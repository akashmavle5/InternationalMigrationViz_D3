# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('./UN_MigrantStockTotal_2015.xlsx', sheetname='Table 1')
df
# Out:
#       Unnamed: 0                                         Unnamed: 1  \
# 0            NaN                                                NaN
# 1            NaN                                                NaN
# 2            NaN                                                NaN
# 3            NaN                                                NaN
# 4            NaN                                                NaN
# 5            NaN                                                NaN
# 6            NaN                                                NaN
# 7            NaN                                                NaN
# 8            NaN                                                NaN
# 9            NaN                                                NaN
# 10           NaN                                                NaN
# 11           NaN                                                NaN
# 12   Sort\norder  Major area, region, country or area of destina...
# ...

# %%
df = pd.read_csv('./sample.csv')
df
# Out:
#     Sort\norder Major area, region, country or area of destination Notes  \
# 0           NaN                                                NaN   NaN
# 1           1.0                                              WORLD   NaN
# 2           2.0                                  Developed regions   (b)
# 3           3.0                                 Developing regions   (c)
# 4           4.0                          Least developed countries   (d)
# 5           5.0  Less developed regions excluding least develop...   NaN
# 6           6.0                                 Sub-Saharan Africa   (e)
# 7           7.0                                             Africa   NaN
# 8           8.0                                     Eastern Africa   NaN
# 9           9.0                                            Burundi   NaN
# 10         10.0                                            Comoros   NaN
# 11         11.0                                           Djibouti   NaN
# ...
